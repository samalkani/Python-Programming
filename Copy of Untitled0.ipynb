# %% [markdown]
# > # Variables & basic operations

# %%
words = "romain"

# %%
words
# Out:
# 'romain'

# %%
number = 8

# %%
number
# Out:
# 8

# %%
number + number
# Out:
# 16

# %%
words = '8'

# %%
number + words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ec862137331a> in <module>
# ----> 1 number + words
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# int() transforms a string into an integer
number + int(words)
# Out:
# 16

# %%
# data types

word = '8' # a string
number = 8 # an integer
number2 = 8.2 # a float

# %% [markdown]
# # Conditional
